# %% [markdown]
# ## List dan Dictionary

# %%
import pandas as pd

# %%
# index selalu dimulai dengan 0, kalo list indeksnya gabisa diubah
teman = ['Joni Gudel', 'Edi Yunani', 'Toni Sulung', 'Retno Mimin']
pd.Series(teman)
# Out:
# 0     Joni Gudel
# 1     Edi Yunani
# 2    Toni Sulung
# 3    Retno Mimin
# dtype: object

# %%
# mengatur label pada dictionary, indeksnya bisa diubah
temanakrab = {3:'Joni Gudel', 2:'Edi Yunani', 1:'Toni Sulung', 0:'Retno Mimin'}
pd.Series(temanakrab)
# Out:
# 3     Joni Gudel
# 2     Edi Yunani
# 1    Toni Sulung
# 0    Retno Mimin
# dtype: object

# %%
# parameter index
pd.Series(data=teman, index=['teman1','teman2','teman3','teman4'])
# Out:
# teman1     Joni Gudel
# teman2     Edi Yunani
# teman3    Toni Sulung
# teman4    Retno Mimin
# dtype: object

# %% [markdown]
# ## Atribut Name

# %%
namateman = pd.Series(teman)
namateman.name = 'Daftar Nama Teman Akrab'
namateman
# Out:
# 0     Joni Gudel
# 1     Edi Yunani
# 2    Toni Sulung
# 3    Retno Mimin
# Name: Daftar Nama Teman Akrab, dtype: object

# %% [markdown]
# ## Method Head() dan Tail()

# %%
# membuat series dari angka 0 sampai 99
angka = pd.Series(range(0,100)) # angka=variabel; .Series()=konstruktor; range()=method; 0=start; 100=stop
angka
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Length: 100, dtype: int64

# %%
# menampilkan 5 data teratas
angka.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
# menampilkan 10 data terbawah
angka.tail(10)
# Out:
# 90    90
# 91    91
# 92    92
# 93    93
# 94    94
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# dtype: int64
