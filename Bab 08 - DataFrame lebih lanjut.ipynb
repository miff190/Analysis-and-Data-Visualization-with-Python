# %% [markdown]
# ## Import Dataset

# %%
import pandas as pd

# akses data melalui url
data_url = 'https://thinkjubilee.com/bola.csv'
pd.read_csv(data_url)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# ## Boolean Mask

# %%
pemainbola = pd.read_csv('https://thinkjubilee.com/bola.csv')
pemainbola['market_value'] > 50
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
# tampilan lebih lengkap
pemainbola[pemainbola['market_value'] > 50]
# Out:
#                 name               club  age position  position_cat  \
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 96       Eden Hazard            Chelsea   26       LW             1
# 244  Kevin De Bruyne    Manchester+City   26       AM             1
# 245    Sergio Aguero    Manchester+City   29       CF             1
# 267       Paul Pogba  Manchester+United   24       CM             2
# 381       Harry Kane          Tottenham   23       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            65.0        4329       12.0  17.10%         264       3
# 96           75.0        4220       10.5   2.30%         224       2
# 244          65.0        2252       10.0  17.50%         199       2
# 245          65.0        4046       11.5   9.70%         175       3
# 267          75.0        7435        8.0  19.50%         115       2
# 381          60.0        4161       12.5  35.10%         224       1
#
# ...

# %%
# tampilan lebih ringkas
pemainbola[pemainbola['market_value'] > 50].shape
# Out:
# (6, 17)

# %% [markdown]
# ## Method unique()
# mengambil data unik gak ada yang sama

# %%
# method unique
pemainbola['nationality'].unique()
# Out:
# array(['Chile', 'Germany', 'Czech Republic', 'England', 'France', 'Spain',
#        'Nigeria', 'Switzerland', 'Wales', 'Brazil', 'Egypt', 'Argentina',
#        'Colombia', 'Bosnia', 'Norway', 'Poland', 'Scotland', 'Congo DR',
#        'Ireland', 'Netherlands', 'Australia', "Cote d'Ivoire", 'Finland',
#        'Cameroon', 'Austria', 'Israel', 'Northern Ireland', 'Canada',
#        'Belgium', 'Iceland', 'Serbia', 'Portugal', 'Ghana', 'South Korea',
#        'Mali', 'Senegal', 'Curacao', 'Denmark', 'Slovenia',
#        'Trinidad and Tobago', 'Bermuda', 'Benin', 'Algeria', 'Jamaica',
#        'Japan', 'Tunisia', 'Croatia', 'Estonia', 'Ecuador', 'Armenia',
#        'Italy', 'Sweden', 'United States', 'Morocco', 'The Gambia',
#        'Kenya', 'Greece', 'Uruguay', 'Romania', 'Venezuela',
#        'New Zealand'], dtype=object)

# %%
# mengetahui jumlah negara yang unik
pemainbola['nationality'].unique().size
# Out:
# 61

# %% [markdown]
# ## Method isin()
# untuk mengetahui data-data yang berada pada kriteria tertentu

# %%
# tampilan bolean mask
pemainbola['nationality'].isin(['Englang','South Korea','Italy'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
# tampilan secara lengkap
pemainbola[pemainbola['nationality'].isin(['Englang','South Korea','Italy'])]
# Out:
#                   name               club  age position  position_cat  \
# 131     Lee Chung-yong     Crystal+Palace   29       RW             1
# 276     Matteo Darmian  Manchester+United   27       RB             3
# 326  Manolo Gabbiadini        Southampton   25       CF             1
# 365      Ki Sung-yueng            Swansea   28       DM             2
# 383      Son Heung-min          Tottenham   25       LW             1
# 412      Stefano Okaka            Watford   27       CF             1
# 458     Angelo Ogbonna           West+Ham   29       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 131           1.5         327        4.5   0.10%          24       4
# 276          12.0        1640        5.5   0.30%          70       2
# 326          15.0        2012        7.0   5.20%          38       2
# 365           7.0         478        5.0   0.00%          41       4
# ...

# %% [markdown]
# ## Method between()
# mendapatkan range nilai dari dataset. Butuh 2 argumen --> nilai terendah & nilai tertinggi

# %%
pemainbola[pemainbola['market_value'].between(65,75)]
# Out:
#                 name               club  age position  position_cat  \
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 96       Eden Hazard            Chelsea   26       LW             1
# 244  Kevin De Bruyne    Manchester+City   26       AM             1
# 245    Sergio Aguero    Manchester+City   29       CF             1
# 267       Paul Pogba  Manchester+United   24       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            65.0        4329       12.0  17.10%         264       3
# 96           75.0        4220       10.5   2.30%         224       2
# 244          65.0        2252       10.0  17.50%         199       2
# 245          65.0        4046       11.5   9.70%         175       3
# 267          75.0        7435        8.0  19.50%         115       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0         Chile            0        4        1         1            0
# ...

# %% [markdown]
# ## Operator dan Method Perbanndingan
# digunakan untuk memfilter dataset. operatornya adalah ==,>,<, dsb

# %%
pemainbola = pd.read_csv('https://thinkjubilee.com/bola.csv')

# para pemain dengan usia dibawah 30 tahun
pemainbola[pemainbola['age'] < 30]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
# kurang dari (<) setara dengan method lt()
pemainbola[pemainbola['age'].lt(30)]

# le() setara dengan <=
# lt() setara dengan <
# gt() setara dengan >
# ge() setara dengan >=
# eq() setara dengan ==
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
# kombinasi lebih 2 kondisi
pemainbola[(pemainbola['market_value'] > 50) & (pemainbola['nationality'] == 'England')]
# Out:
#            name       club  age position  position_cat  market_value  \
# 381  Harry Kane  Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 381            0        2       17         1            0

# %%
# buat lebih spesifik lagi
pemainbola[
    (pemainbola['market_value'] > 50) &
    (pemainbola['nationality'] == 'England') &
    (pemainbola['age'] < 30)]
# Out:
#            name       club  age position  position_cat  market_value  \
# 381  Harry Kane  Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 381            0        2       17         1            0

# %%
# manfaatkan variabel biar gak terlalu pusing
usia = pemainbola['age'] < 30
klub = pemainbola['club'] == 'Arsenal'
market = pemainbola['market_value'] > 30

# terapkan ke penampil
pemainbola[usia & klub & market]
# Out:
#                    name     club  age position  position_cat  market_value  \
# 0        Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1            Mesut Ozil  Arsenal   28       AM             1          50.0
# 10         Granit Xhaka  Arsenal   24       DM             2          35.0
# 11         Granit Xhaka  Arsenal   24       DM             2          35.0
# 15         Aaron Ramsey  Arsenal   26       CM             2          35.0
# 31  Alexandre Lacazette  Arsenal   26       CF             1          40.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 0         4329       12.0  17.10%         264       3        Chile
# 1         4395        9.5   5.60%         167       2      Germany
# 10        1815        5.5   2.00%          85       2  Switzerland
# 11        1815        5.5   2.00%          85       2  Switzerland
# 15        1040        7.0   5.10%          56       1        Wales
# ...

# %%
# gunakan operator NOT (~)
pemainbola[usia & ~klub & market].head()
# Out:
#                  name     club  age position  position_cat  market_value  \
# 96        Eden Hazard  Chelsea   26       LW             1          75.0
# 97        Diego Costa  Chelsea   28       CF             1          50.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 105           Willian  Chelsea   28       RW             1          32.0
# 107     Nemanja Matic  Chelsea   28       DM             2          35.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 96         4220       10.5   2.30%         224       2     Belgium
# 97         4454       10.0   3.00%         196       2       Spain
# 102        1260        5.5  18.50%         141       2     Belgium
# 105        1165        7.0   9.00%         114       3      Brazil
# 107         892        5.0   5.00%         105       2      Serbia
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 96             0        3        5         1            0
# ...

# %% [markdown]
# ## Mengenal 2D Indexing
# indeksing menurut baris dan kolom sekaligus

# %%
# indexing 2D
pemainbola.loc[usia & ~klub & market,
              ['name','club','nationality','market_value']]
# Out:
#                    name               club nationality  market_value
# 96          Eden Hazard            Chelsea     Belgium          75.0
# 97          Diego Costa            Chelsea       Spain          50.0
# 102    Thibaut Courtois            Chelsea     Belgium          40.0
# 105             Willian            Chelsea      Brazil          32.0
# 107       Nemanja Matic            Chelsea      Serbia          35.0
# 108      N%27Golo Kante            Chelsea      France          50.0
# 217     Roberto Firmino          Liverpool      Brazil          38.0
# 218   Philippe Coutinho          Liverpool      Brazil          45.0
# 219          Sadio Mane          Liverpool     Senegal          40.0
# 241       Mohamed Salah          Liverpool       Egypt          35.0
# 244     Kevin De Bruyne    Manchester+City     Belgium          65.0
# 245       Sergio Aguero    Manchester+City   Argentina          65.0
# 246     Raheem Sterling    Manchester+City     England          45.0
# ...
