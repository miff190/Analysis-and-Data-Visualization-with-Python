# %% [markdown]
# ## Menulis kode program

# %%
halo = "Halo Dunia"
print("nama saya Joni Gudel")
print(halo)
# Out:
# nama saya Joni Gudel
# Halo Dunia

# %% [markdown]
# ## Pandas

# %%
# mengimport pandas
import pandas as pd

# %%
# mengecek pandas
print(pd.__version__)
# Out:
# 2.2.2
