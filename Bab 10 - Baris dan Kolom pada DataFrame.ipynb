# %%
# import dataset
import pandas as pd
pemainbola = pd.read_csv('https://thinkjubilee.com/bola.csv')

# tampilan awal
pemainbola
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# ## Method .iloc[]
# sama kaya .loc[] tapi data dipilih berdasarkan index

# %%
# mengambil 5 baris data dan 3 buah kolom
pemainbola_kecil = pemainbola.iloc[:5,0:3] # <-- :5=baris=mulai dari index 0 sampai 4; 0:3=kolom=mulai dari index 0 sampai 3
pemainbola_kecil
# Out:
#                 name     club  age
# 0     Alexis Sanchez  Arsenal   28
# 1         Mesut Ozil  Arsenal   28
# 2          Petr Cech  Arsenal   35
# 3       Theo Walcott  Arsenal   28
# 4  Laurent Koscielny  Arsenal   31

# %% [markdown]
# ## Method .insert()
# menambah kolom dan data baru menggunakan series

# %%
# tampilan awal
pemainbola_kecil
# Out:
#                 name     club  age
# 0     Alexis Sanchez  Arsenal   28
# 1         Mesut Ozil  Arsenal   28
# 2          Petr Cech  Arsenal   35
# 3       Theo Walcott  Arsenal   28
# 4  Laurent Koscielny  Arsenal   31

# %%
# buat series dulu
nickname = pd.Series(['Alex','Mesut','Petr','Theo','Laurent'])
nickname
# Out:
# 0       Alex
# 1      Mesut
# 2       Petr
# 3       Theo
# 4    Laurent
# dtype: object

# %%
# gunakan insert untuk nambah kolom baru
pemainbola_kecil.insert(0,'nickname',nickname)
pemainbola_kecil

# ada tiga argumen dalam .insert()
# 0=index=menentukan posisi kolom (0 berarti paling kiri)
# 'nickname'=nama kolom yang diinginkan
# nickname=parameter data yang ditambahkan
# Out:
#   nickname               name     club  age
# 0     Alex     Alexis Sanchez  Arsenal   28
# 1    Mesut         Mesut Ozil  Arsenal   28
# 2     Petr          Petr Cech  Arsenal   35
# 3     Theo       Theo Walcott  Arsenal   28
# 4  Laurent  Laurent Koscielny  Arsenal   31

# %% [markdown]
# ## Method .assign()
# untuk menambah kolom dan data baru dengan list

# %%
# tampilan awal
pemainbola_kecil
# Out:
#   nickname               name     club  age
# 0     Alex     Alexis Sanchez  Arsenal   28
# 1    Mesut         Mesut Ozil  Arsenal   28
# 2     Petr          Petr Cech  Arsenal   35
# 3     Theo       Theo Walcott  Arsenal   28
# 4  Laurent  Laurent Koscielny  Arsenal   31

# %%
# tambah kolom ['goals'] posisi paling kanan
pemainbola_kecil = pemainbola_kecil.assign(goals=[15,20,18,11,14])
pemainbola_kecil
# Out:
#   nickname               name     club  age  goals
# 0     Alex     Alexis Sanchez  Arsenal   28     15
# 1    Mesut         Mesut Ozil  Arsenal   28     20
# 2     Petr          Petr Cech  Arsenal   35     18
# 3     Theo       Theo Walcott  Arsenal   28     11
# 4  Laurent  Laurent Koscielny  Arsenal   31     14

# %% [markdown]
# ## Method .drop()
# menghapus kolom. Argumennya berbentuk array atau list

# %%
# tampilan awal
pemainbola_kecil
# Out:
#   nickname               name     club  age  goals
# 0     Alex     Alexis Sanchez  Arsenal   28     15
# 1    Mesut         Mesut Ozil  Arsenal   28     20
# 2     Petr          Petr Cech  Arsenal   35     18
# 3     Theo       Theo Walcott  Arsenal   28     11
# 4  Laurent  Laurent Koscielny  Arsenal   31     14

# %%
# hapus kolom ['nickname']
pemainbola_kecil.drop(columns=['nickname'], inplace=True) # <-- gunakan inplace=True untuk eksekusi langsung
pemainbola_kecil
# Out:
#                 name     club  age  goals
# 0     Alexis Sanchez  Arsenal   28     15
# 1         Mesut Ozil  Arsenal   28     20
# 2          Petr Cech  Arsenal   35     18
# 3       Theo Walcott  Arsenal   28     11
# 4  Laurent Koscielny  Arsenal   31     14

# %% [markdown]
# ## Method .append()
# menambah baris baru ke dataset

# %%
pemainbola_kecil
# Out:
#                 name     club  age  goals
# 0     Alexis Sanchez  Arsenal   28     15
# 1         Mesut Ozil  Arsenal   28     20
# 2          Petr Cech  Arsenal   35     18
# 3       Theo Walcott  Arsenal   28     11
# 4  Laurent Koscielny  Arsenal   31     14

# %%
# gunakan dictionary untuk pedoman nambahin data
namajoni = pd.Series({
    'name':'Joni',
    'club': 'Juventus',
    'age': 30,
    'goals': 15
})

# terapkan dictionary ke append
pemainbola_kecil.append(namajoni)

# <-- ini bakal error karena sudah tidak berlaku lagi di pandas 2.0
# solusinnya pakai .concat() atau downgrade pandas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4b1664ae5cd8> in <cell line: 10>()
#       8
#       9 # terapkan dictionary ke append
# ---> 10 pemainbola_kecil.append(namajoni) # <-- ini bakal error karena sudah tidak berlaku lagi di pandas 2.0
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# ALTERNATIF
# gunakan dictionary untuk pedoman nambahin data
namajoni = pd.Series({
    'name':'Joni Gudel',
    'club': 'Juventus',
    'age': 30,
    'goals': 15
})

# Ubah Series menjadi DataFrame
df_namajoni = pd.DataFrame([namajoni])

# menggunakan .concat()
pd.concat([pemainbola_kecil, df_namajoni])
# Out:
#                 name      club  age  goals
# 0     Alexis Sanchez   Arsenal   28     15
# 1         Mesut Ozil   Arsenal   28     20
# 2          Petr Cech   Arsenal   35     18
# 3       Theo Walcott   Arsenal   28     11
# 4  Laurent Koscielny   Arsenal   31     14
# 0         Joni Gudel  Juventus   30     15

# %%
# gunakan ignore_index=True agar indeksnya ngurut dari 0
df_baru = pd.concat([pemainbola_kecil, df_namajoni], ignore_index=True)

# masukan gabungan df tadi ke df_baru
df_baru
# Out:
#                 name      club  age  goals
# 0     Alexis Sanchez   Arsenal   28     15
# 1         Mesut Ozil   Arsenal   28     20
# 2          Petr Cech   Arsenal   35     18
# 3       Theo Walcott   Arsenal   28     11
# 4  Laurent Koscielny   Arsenal   31     14
# 5         Joni Gudel  Juventus   30     15

# %%
# menambah beberapa data sekaligus
namapemainbaru = pd.DataFrame({
    'name': ['Toni Sulung','Edi Yunani'],
    'club': ['Juventus','Arsenal'],
    'age': [31,28],
    'goals': [6,7]
})

# menggunakan .concat()
pd.concat([df_baru, namapemainbaru], ignore_index=True)
# Out:
#                 name      club  age  goals
# 0     Alexis Sanchez   Arsenal   28     15
# 1         Mesut Ozil   Arsenal   28     20
# 2          Petr Cech   Arsenal   35     18
# 3       Theo Walcott   Arsenal   28     11
# 4  Laurent Koscielny   Arsenal   31     14
# 5         Joni Gudel  Juventus   30     15
# 6        Toni Sulung  Juventus   31      6
# 7         Edi Yunani   Arsenal   28      7
